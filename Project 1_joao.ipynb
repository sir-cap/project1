# %%
import pandas as pd

# %%
data = pd.read_csv('fifa21_male2.csv')
pd.set_option('display.max_columns', None)
# Out:
# /var/folders/0m/d3zbckcj1zd772z7m1w0_xgc0000gn/T/ipykernel_35379/1917005979.py:1: DtypeWarning: Columns (78) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('fifa21_male2.csv')

# %%
data
# Out:
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# ...

# %%
data.columns = data.columns.str.lower()

# %%
data = data.drop(['id','player photo','club logo','flag photo','team & contract','gender'],axis=1)

# %%
data
# Out:
#                   name  age  ova            nationality           club  bov  \
# 0          G. Pasquale   33   69                  Italy        Udinese   71
# 1          Luis García   37   71                  Spain      KAS Eupen   70
# 2              J. Cole   33   71                England  Coventry City   71
# 3             D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70
# 4              Iniesta   36   81                  Spain    Vissel Kobe   82
# ...                ...  ...  ...                    ...            ...  ...
# 17120       A. Medioub   22   64                 France     CD Tondela   66
# 17121       W. Rickard   18   56                  Wales        Burnley   58
# 17122       C. Barrett   18   56                England        Burnley   56
# 17123   J. Gazibegović   20   62     Bosnia Herzegovina  SK Sturm Graz   62
# 17124  Pablo Rodríguez   18   59                  Spain          Lecce   61
#
# ...

# %%
data.iloc[:, 0:33]
# Out:
#                   name  age  ova            nationality           club  bov  \
# 0          G. Pasquale   33   69                  Italy        Udinese   71
# 1          Luis García   37   71                  Spain      KAS Eupen   70
# 2              J. Cole   33   71                England  Coventry City   71
# 3             D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70
# 4              Iniesta   36   81                  Spain    Vissel Kobe   82
# ...                ...  ...  ...                    ...            ...  ...
# 17120       A. Medioub   22   64                 France     CD Tondela   66
# 17121       W. Rickard   18   56                  Wales        Burnley   58
# 17122       C. Barrett   18   56                England        Burnley   56
# 17123   J. Gazibegović   20   62     Bosnia Herzegovina  SK Sturm Graz   62
# 17124  Pablo Rodríguez   18   59                  Spain          Lecce   61
#
# ...

# %%
data.iloc[:, 0:33].isna().sum()
# Out:
# name                    0
# age                     0
# ova                     0
# nationality             0
# club                   23
# bov                     0
# bp                      0
# position              413
# pot                     0
# height                  0
# weight                  0
# foot                    0
# growth                  0
# joined                 58
# loan date end       16215
# value                   0
# wage                    0
# release clause          0
# contract                0
# attacking               0
# crossing                0
# finishing               0
# heading accuracy        0
# short passing           0
# volleys                58
# skill                   0
# dribbling               0
# curve                  58
# fk accuracy             0
# long passing            0
# ball control            0
# movement                0
# acceleration            0
# dtype: int64

# %%
data['club'] = data['club'].fillna("without club")

# %%
data[data['position'].isnull()]
# Out:
#              name  age  ova            nationality                  club  bov  \
# 3        D. Yorke   36   68  Trinidad &amp; Tobago            Sunderland   70
# 13    S. Campbell   35   75                England      Newcastle United   75
# 15      D. Hamann   36   61                Germany    Milton Keynes Dons   67
# 16      A. Okocha   33   73                Nigeria             Hull City   76
# 17           Zulu   26   66                 Brazil       Pohang Steelers   66
# ...           ...  ...  ...                    ...                   ...  ...
# 1530          Ivo   33   75                 Brazil       Henan Jianye FC   76
# 1549     G. Vives   36   72                  Italy  FC Pro Vercelli 1892   72
# 1554    S. Burrai   32   69                  Italy             Pordenone   69
# 1560    J. García   32   72              Argentina           Racing Club   72
# 1565     T. Cywka   31   63                 Poland           Lech Poznań   64
#
# ...

# %%
data['position'] = data['c'].fillna("without club")

# %%
data.fillna(method='ffill', inplace=false)

# %%
data
# Out:
#                   name  age  ova            nationality           club  bov  \
# 0          G. Pasquale   33   69                  Italy        Udinese   71
# 1          Luis García   37   71                  Spain      KAS Eupen   70
# 2              J. Cole   33   71                England  Coventry City   71
# 3             D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70
# 4              Iniesta   36   81                  Spain    Vissel Kobe   82
# ...                ...  ...  ...                    ...            ...  ...
# 17120       A. Medioub   22   64                 France     CD Tondela   66
# 17121       W. Rickard   18   56                  Wales        Burnley   58
# 17122       C. Barrett   18   56                England        Burnley   56
# 17123   J. Gazibegović   20   62     Bosnia Herzegovina  SK Sturm Graz   62
# 17124  Pablo Rodríguez   18   59                  Spain          Lecce   61
#
# ...

# %%
value1 = data.loc[0, 'value']

# %%
value1 = value1.replace('€','')
value1 = value1.replace('K','000')
value1
# Out:
# '600000'
